# %% [markdown]
# <a href="https://colab.research.google.com/github/vekteo/Digit_Span_jsPsych/blob/main/Digit_span_jsPsych_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Code for preprocessing the Digit span task (jsPsych)**
#
# 1. Click the FOLDER ikon in the left column (last icon)
# 2. In the opening window, click the UPLOAD icon (first icon) (if another window opens before this step, click OK)
# 3. In the opening window, choose the Digit span outputs for the upload (e.g., "_Subject_01_Session_1_output.csv")
# 4. Run the coe with the Runtime --> Run all option
# 5. If the code runs correctly, it will download a .csv file to your local machine
# ---
#
#
#
# ---

# %%
import glob
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
from google.colab import files

# %%
# get data file names
filenames = glob.glob("*.csv")
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, encoding='ISO-8859-1'))

# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)
big_frame
# Out:
#     ï»¿Event Index  UTC Timestamp  ...           responses  digit_span
# 0                1   1.644082e+12  ...                 NaN         NaN
# 1                2   1.644082e+12  ...                 NaN         NaN
# 2                3   1.644082e+12  ...                 NaN         NaN
# 3                4   1.644082e+12  ...                 NaN         NaN
# 4                5   1.644082e+12  ...                 NaN         NaN
# ..             ...            ...  ...                 ...         ...
# 317            149   1.643920e+12  ...                 NaN         NaN
# 318            150   1.643920e+12  ...  {"answer":"99999"}         NaN
# 319            151   1.643920e+12  ...                 NaN         7.0
# 320            152   1.643920e+12  ...                 NaN         NaN
# 321    END OF FILE            NaN  ...                 NaN         NaN
#
# [322 rows x 46 columns]

# %%
#leave only the important columns
df = big_frame.loc[:, ['Participant Public ID', 'digit_span']]
df.head()
# Out:
#   Participant Public ID  digit_span
# 0              mxs1w0o7         NaN
# 1              mxs1w0o7         NaN
# 2              mxs1w0o7         NaN
# 3              mxs1w0o7         NaN
# 4              mxs1w0o7         NaN

# %%
#drop instruction, feedback trials
df = df.dropna(subset=['digit_span'])
df.head()
# Out:
#     Participant Public ID  digit_span
# 93               mxs1w0o7         5.0
# 167              5kwv1ykm         4.0
# 319              x07ksd1p         7.0

# %%
#save data
df.to_csv("digitspan.csv",index=False)
files.download("digitspan.csv")
